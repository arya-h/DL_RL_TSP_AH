# %%
#100 nodes variant

from env_v4 import Env_tsp
from config import Config

# %%
cfg = Config()
env = Env_tsp(cfg)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class AE(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        self.encoder_hidden_layer = nn.Linear(
            in_features=kwargs["input_shape"], out_features=64
        )
        self.encoder_output_layer = nn.Linear(
            in_features=64, out_features=64
        )
        self.decoder_hidden_layer = nn.Linear(
            in_features=64, out_features=64
        )
        self.decoder_output_layer = nn.Linear(
            in_features=64, out_features=kwargs["input_shape"]
        )
        
    def encode(self, x):
        activation = self.encoder_hidden_layer(x)
        activation = torch.relu(activation)
        code = self.encoder_output_layer(activation)
        code = torch.relu(code)
        return code
    
    def decode(self, code):
        activation = self.decoder_hidden_layer(code)
        activation = torch.relu(activation)
        activation = self.decoder_output_layer(activation)
        reconstructed = torch.relu(activation)
        return reconstructed

    def forward(self, features):
        encoded = self.encode(features)
        reconstructed = self.decode(tmp)
        return reconstructed

# %%
#  use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# create a model from `AE` autoencoder class
# load it to the specified device, either gpu or cpu
model = AE(input_shape=2).to(device)

# create an optimizer object
# Adam optimizer with learning rate 1e-3
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# mean-squared error loss
criterion = nn.MSELoss()

# %%
from torch.utils.data import Dataset, DataLoader

class DistMatrixDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, data_list, root_dir="", transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.data = data_list
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        if self.transform:
            sample = self.transform(sample)

        return self.data[idx]

# %%
import torch.utils.data as data
from torch.utils.data.dataset import random_split

batch = env.get_batch_nodes(50000)

dataset = DistMatrixDataset(batch)
loader = DataLoader(dataset)

# Random split
train_set, valid_set = random_split(dataset, [45000, 5000])

print(len(train_set))
print(len(valid_set))
# Out:
# 45000
# 5000

# %%
train_loader = DataLoader(
    train_set, batch_size=128, shuffle=True, num_workers=4, pin_memory=True
)

test_loader = torch.utils.data.DataLoader(
    valid_set, batch_size=32, shuffle=False, num_workers=4
)

# %%
epochs = 50

for epoch in range(epochs):
    loss = 0
    for batch_features in train_loader:
        # reshape mini-batch data to [N, 784] matrix
        # load it to the active device
        batch_features = batch_features.view(-1,2).to(device)
        
        # reset the gradients back to zero
        # PyTorch accumulates gradients on subsequent backward passes
        optimizer.zero_grad()
        
        # compute reconstructions
        outputs = model(batch_features)
        
        # compute training reconstruction loss
        train_loss = criterion(outputs, batch_features)
        
        # compute accumulated gradients
        train_loss.backward()
        
        # perform parameter update based on current gradients
        optimizer.step()
        
        # add the mini-batch training loss to epoch loss
        loss += train_loss.item()
        if epoch == 48:
            print(batch_features[0])
            print(outputs[0])
    
    # compute the epoch training loss
    loss = loss / len(train_loader)
    

    
    # display the epoch training loss
    print("epoch : {}/{}, loss = {:.6f}".format(epoch + 1, epochs, loss))
# Out:
# epoch : 1/50, loss = 0.023611
# epoch : 2/50, loss = 0.000016
# epoch : 3/50, loss = 0.000006
# epoch : 4/50, loss = 0.000003
# epoch : 5/50, loss = 0.000002
# epoch : 6/50, loss = 0.000002
# epoch : 7/50, loss = 0.000001
# epoch : 8/50, loss = 0.000001
# epoch : 9/50, loss = 0.000002
# epoch : 10/50, loss = 0.000003
# epoch : 11/50, loss = 0.000002
# epoch : 12/50, loss = 0.000003
# epoch : 13/50, loss = 0.000003
# epoch : 14/50, loss = 0.000004
# epoch : 15/50, loss = 0.000003
# epoch : 16/50, loss = 0.000003
# epoch : 17/50, loss = 0.000004
# epoch : 18/50, loss = 0.000003
# epoch : 19/50, loss = 0.000004
# epoch : 20/50, loss = 0.000003
# epoch : 21/50, loss = 0.000004
# epoch : 22/50, loss = 0.000003
# epoch : 23/50, loss = 0.000004
# epoch : 24/50, loss = 0.000003
# epoch : 25/50, loss = 0.000004
# epoch : 26/50, loss = 0.000004
# epoch : 27/50, loss = 0.000003
# epoch : 28/50, loss = 0.000003
# epoch : 29/50, loss = 0.000003
# epoch : 30/50, loss = 0.000003
# epoch : 31/50, loss = 0.000004
# epoch : 32/50, loss = 0.000003
# epoch : 33/50, loss = 0.000003
# epoch : 34/50, loss = 0.000003
# epoch : 35/50, loss = 0.000003
# epoch : 36/50, loss = 0.000003
# epoch : 37/50, loss = 0.000003
# epoch : 38/50, loss = 0.000003
# epoch : 39/50, loss = 0.000003
# epoch : 40/50, loss = 0.000003
# epoch : 41/50, loss = 0.000003
# epoch : 42/50, loss = 0.000002
# epoch : 43/50, loss = 0.000003
# epoch : 44/50, loss = 0.000003
# epoch : 45/50, loss = 0.000003
# epoch : 46/50, loss = 0.000003
# epoch : 47/50, loss = 0.000003
# epoch : 48/50, loss = 0.000003
# tensor([0.0474, 0.3695])
# tensor([0.0457, 0.3708], grad_fn=<SelectBackward>)
# tensor([0.6369, 0.7005])
# tensor([0.6407, 0.6984], grad_fn=<SelectBackward>)
# tensor([0.1545, 0.8372])
# tensor([0.1509, 0.8391], grad_fn=<SelectBackward>)
# tensor([0.7933, 0.0166])
# tensor([0.7973, 0.0144], grad_fn=<SelectBackward>)
# tensor([0.1539, 0.9780])
# tensor([0.1512, 0.9797], grad_fn=<SelectBackward>)
# tensor([0.2443, 0.5953])
# tensor([0.2452, 0.5941], grad_fn=<SelectBackward>)
# tensor([0.7876, 0.3252])
# tensor([0.7880, 0.3257], grad_fn=<SelectBackward>)
# tensor([0.0130, 0.0747])
# tensor([0.0115, 0.0748], grad_fn=<SelectBackward>)
# tensor([0.7216, 0.3270])
# tensor([0.7244, 0.3268], grad_fn=<SelectBackward>)
# tensor([0.8807, 0.8032])
# tensor([0.8770, 0.8031], grad_fn=<SelectBackward>)
# tensor([0.2453, 0.1949])
# tensor([0.2471, 0.1946], grad_fn=<SelectBackward>)
# tensor([0.0042, 0.6860])
# tensor([0.0016, 0.6873], grad_fn=<SelectBackward>)
# tensor([0.2909, 0.9526])
# tensor([0.2917, 0.9528], grad_fn=<SelectBackward>)
# tensor([0.1501, 0.0420])
# tensor([0.1503, 0.0418], grad_fn=<SelectBackward>)
# tensor([0.1385, 0.8180])
# tensor([0.1373, 0.8186], grad_fn=<SelectBackward>)
# tensor([0.0753, 0.3808])
# tensor([0.0767, 0.3807], grad_fn=<SelectBackward>)
# tensor([0.3642, 0.8630])
# tensor([0.3619, 0.8637], grad_fn=<SelectBackward>)
# tensor([0.0568, 0.9118])
# tensor([0.0584, 0.9113], grad_fn=<SelectBackward>)
# tensor([0.6679, 0.1650])
# tensor([0.6668, 0.1654], grad_fn=<SelectBackward>)
# tensor([0.1986, 0.4858])
# tensor([0.1993, 0.4860], grad_fn=<SelectBackward>)
# tensor([0.2266, 0.7684])
# tensor([0.2267, 0.7682], grad_fn=<SelectBackward>)
# tensor([0.7499, 0.2756])
# tensor([0.7490, 0.2758], grad_fn=<SelectBackward>)
# tensor([0.0769, 0.4208])
# tensor([0.0776, 0.4204], grad_fn=<SelectBackward>)
# tensor([0.4852, 0.0480])
# tensor([0.4843, 0.0481], grad_fn=<SelectBackward>)
# tensor([0.9124, 0.8882])
# tensor([0.9140, 0.8874], grad_fn=<SelectBackward>)
# tensor([0.0620, 0.9920])
# tensor([0.0620, 0.9920], grad_fn=<SelectBackward>)
# tensor([0.5291, 0.3279])
# tensor([0.5291, 0.3276], grad_fn=<SelectBackward>)
# tensor([0.9941, 0.1346])
# tensor([0.9945, 0.1349], grad_fn=<SelectBackward>)
# tensor([0.3186, 0.3795])
# tensor([0.3180, 0.3794], grad_fn=<SelectBackward>)
# tensor([0.4348, 0.8884])
# tensor([0.4361, 0.8886], grad_fn=<SelectBackward>)
# tensor([0.4004, 0.1950])
# tensor([0.3995, 0.1948], grad_fn=<SelectBackward>)
# tensor([0.1632, 0.8940])
# tensor([0.1641, 0.8943], grad_fn=<SelectBackward>)
# tensor([0.4914, 0.9265])
# tensor([0.4906, 0.9260], grad_fn=<SelectBackward>)
# tensor([0.8117, 0.6159])
# tensor([0.8123, 0.6166], grad_fn=<SelectBackward>)
# tensor([0.5146, 0.7570])
# tensor([0.5146, 0.7562], grad_fn=<SelectBackward>)
# tensor([0.9355, 0.8195])
# tensor([0.9351, 0.8208], grad_fn=<SelectBackward>)
# tensor([0.2945, 0.5439])
# tensor([0.2948, 0.5430], grad_fn=<SelectBackward>)
# tensor([0.6874, 0.8199])
# tensor([0.6867, 0.8213], grad_fn=<SelectBackward>)
# tensor([0.9520, 0.0936])
# tensor([0.9527, 0.0919], grad_fn=<SelectBackward>)
# tensor([0.8041, 0.0776])
# tensor([0.8041, 0.0791], grad_fn=<SelectBackward>)
# tensor([0.1139, 0.2127])
# tensor([0.1139, 0.2117], grad_fn=<SelectBackward>)
# tensor([0.8277, 0.5457])
# tensor([0.8284, 0.5476], grad_fn=<SelectBackward>)
# tensor([0.2415, 0.4108])
# tensor([0.2412, 0.4093], grad_fn=<SelectBackward>)
# tensor([0.6357, 0.9692])
# tensor([0.6370, 0.9719], grad_fn=<SelectBackward>)
# tensor([0.2279, 0.5779])
# tensor([0.2267, 0.5756], grad_fn=<SelectBackward>)
# tensor([0.6906, 0.5744])
# tensor([0.6921, 0.5775], grad_fn=<SelectBackward>)
# tensor([0.9459, 0.3254])
# tensor([0.9443, 0.3206], grad_fn=<SelectBackward>)
# tensor([0.5824, 0.1429])
# tensor([0.5836, 0.1462], grad_fn=<SelectBackward>)
# tensor([0.1744, 0.8211])
# tensor([0.1730, 0.8170], grad_fn=<SelectBackward>)
# tensor([0.9783, 0.0824])
# tensor([0.9795, 0.0883], grad_fn=<SelectBackward>)
# tensor([0.7629, 0.9524])
# tensor([0.7613, 0.9456], grad_fn=<SelectBackward>)
# tensor([0.6119, 0.4605])
# tensor([0.6131, 0.4660], grad_fn=<SelectBackward>)
# tensor([0.8336, 0.3742])
# tensor([0.8323, 0.3674], grad_fn=<SelectBackward>)
# tensor([0.0219, 0.6503])
# tensor([0.0228, 0.6558], grad_fn=<SelectBackward>)
# tensor([0.5302, 0.7021])
# tensor([0.5286, 0.6958], grad_fn=<SelectBackward>)
# tensor([0.7343, 0.7175])
# tensor([0.7361, 0.7235], grad_fn=<SelectBackward>)
# tensor([0.6073, 0.3051])
# tensor([0.6057, 0.3013], grad_fn=<SelectBackward>)
# tensor([0.4374, 0.0425])
# tensor([0.4383, 0.0448], grad_fn=<SelectBackward>)
# tensor([0.7999, 0.9101])
# tensor([0.7988, 0.9085], grad_fn=<SelectBackward>)
# tensor([0.1040, 0.8153])
# tensor([0.1034, 0.8152], grad_fn=<SelectBackward>)
# tensor([0.9217, 0.6630])
# tensor([0.9220, 0.6650], grad_fn=<SelectBackward>)
# tensor([0.7542, 0.3899])
# tensor([0.7538, 0.3871], grad_fn=<SelectBackward>)
# tensor([0.9392, 0.7227])
# tensor([0.9405, 0.7267], grad_fn=<SelectBackward>)
# tensor([0.0489, 0.2308])
# tensor([0.0480, 0.2287], grad_fn=<SelectBackward>)
# tensor([0.4639, 0.8212])
# tensor([0.4654, 0.8246], grad_fn=<SelectBackward>)
# tensor([0.7980, 0.1146])
# tensor([0.7966, 0.1119], grad_fn=<SelectBackward>)
# tensor([0.9859, 0.8024])
# tensor([0.9874, 0.8051], grad_fn=<SelectBackward>)
# tensor([0.1091, 0.3873])
# tensor([0.1082, 0.3869], grad_fn=<SelectBackward>)
# tensor([0.3097, 0.2464])
# tensor([0.3097, 0.2463], grad_fn=<SelectBackward>)
# tensor([0.6625, 0.7763])
# tensor([0.6626, 0.7775], grad_fn=<SelectBackward>)
# tensor([0.6174, 0.4108])
# tensor([0.6168, 0.4092], grad_fn=<SelectBackward>)
# tensor([0.7065, 0.0294])
# tensor([0.7069, 0.0313], grad_fn=<SelectBackward>)
# tensor([0.7258, 0.5410])
# tensor([0.7246, 0.5388], grad_fn=<SelectBackward>)
# tensor([0.0064, 0.6986])
# tensor([0.0065, 0.7016], grad_fn=<SelectBackward>)
# tensor([0.0299, 0.0813])
# tensor([0.0287, 0.0810], grad_fn=<SelectBackward>)
# tensor([0.8636, 0.9503])
# tensor([0.8649, 0.9520], grad_fn=<SelectBackward>)
# tensor([0.6252, 0.5613])
# tensor([0.6244, 0.5606], grad_fn=<SelectBackward>)
# tensor([0.1685, 0.1840])
# tensor([0.1685, 0.1841], grad_fn=<SelectBackward>)
# tensor([0.2825, 0.9810])
# tensor([0.2826, 0.9815], grad_fn=<SelectBackward>)
# tensor([0.9385, 0.0215])
# tensor([0.9381, 0.0205], grad_fn=<SelectBackward>)
# tensor([0.0177, 0.7626])
# tensor([0.0186, 0.7647], grad_fn=<SelectBackward>)
# tensor([0.9499, 0.4018])
# tensor([0.9490, 0.4001], grad_fn=<SelectBackward>)
# tensor([0.4111, 0.5409])
# tensor([0.4118, 0.5420], grad_fn=<SelectBackward>)
# tensor([0.1452, 0.2038])
# tensor([0.1448, 0.2031], grad_fn=<SelectBackward>)
# tensor([0.6980, 0.8943])
# tensor([0.6987, 0.8955], grad_fn=<SelectBackward>)
# tensor([0.1341, 0.5941])
# tensor([0.1335, 0.5931], grad_fn=<SelectBackward>)
# tensor([0.3766, 0.0268])
# tensor([0.3765, 0.0280], grad_fn=<SelectBackward>)
# tensor([0.6970, 0.3554])
# tensor([0.6970, 0.3552], grad_fn=<SelectBackward>)
# tensor([0.3138, 0.4624])
# tensor([0.3136, 0.4621], grad_fn=<SelectBackward>)
# tensor([0.6726, 0.6375])
# tensor([0.6728, 0.6382], grad_fn=<SelectBackward>)
# tensor([0.2302, 0.6096])
# tensor([0.2297, 0.6089], grad_fn=<SelectBackward>)
# tensor([0.2569, 0.5413])
# tensor([0.2571, 0.5418], grad_fn=<SelectBackward>)
# tensor([0.6275, 0.7288])
# tensor([0.6270, 0.7279], grad_fn=<SelectBackward>)
# tensor([0.5394, 0.0423])
# tensor([0.5397, 0.0426], grad_fn=<SelectBackward>)
# tensor([0.0850, 0.4959])
# tensor([0.0845, 0.4952], grad_fn=<SelectBackward>)
# tensor([0.7369, 0.3074])
# tensor([0.7371, 0.3078], grad_fn=<SelectBackward>)
# tensor([0.2751, 0.8951])
# tensor([0.2750, 0.8947], grad_fn=<SelectBackward>)
# tensor([0.0092, 0.2953])
# tensor([0.0089, 0.2955], grad_fn=<SelectBackward>)
# tensor([0.2145, 0.7276])
# tensor([0.2147, 0.7275], grad_fn=<SelectBackward>)
# tensor([0.5040, 0.5629])
# tensor([0.5040, 0.5628], grad_fn=<SelectBackward>)
# tensor([0.5037, 0.6028])
# tensor([0.5039, 0.6030], grad_fn=<SelectBackward>)
# tensor([0.5409, 0.4369])
# tensor([0.5407, 0.4365], grad_fn=<SelectBackward>)
# tensor([0.3527, 0.0992])
# tensor([0.3531, 0.0989], grad_fn=<SelectBackward>)
# tensor([0.3067, 0.6694])
# tensor([0.3067, 0.6689], grad_fn=<SelectBackward>)
# tensor([0.8771, 0.8572])
# tensor([0.8774, 0.8580], grad_fn=<SelectBackward>)
# tensor([0.1873, 0.3398])
# tensor([0.1871, 0.3396], grad_fn=<SelectBackward>)
# tensor([0.2938, 0.0702])
# tensor([0.2941, 0.0699], grad_fn=<SelectBackward>)
# tensor([0.1409, 0.6226])
# tensor([0.1410, 0.6222], grad_fn=<SelectBackward>)
# tensor([0.1092, 0.0533])
# tensor([0.1089, 0.0540], grad_fn=<SelectBackward>)
# tensor([0.4404, 0.5396])
# tensor([0.4404, 0.5393], grad_fn=<SelectBackward>)
# tensor([0.3886, 0.4560])
# tensor([0.3887, 0.4561], grad_fn=<SelectBackward>)
# tensor([0.2001, 0.7956])
# tensor([0.2001, 0.7955], grad_fn=<SelectBackward>)
# tensor([0.0075, 0.4233])
# tensor([0.0077, 0.4233], grad_fn=<SelectBackward>)
# tensor([0.0819, 0.8421])
# tensor([0.0816, 0.8423], grad_fn=<SelectBackward>)
# tensor([0.5052, 0.4168])
# tensor([0.5052, 0.4166], grad_fn=<SelectBackward>)
# tensor([0.9381, 0.1292])
# tensor([0.9384, 0.1293], grad_fn=<SelectBackward>)
# tensor([0.4304, 0.8058])
# tensor([0.4303, 0.8056], grad_fn=<SelectBackward>)
# tensor([0.9376, 0.6990])
# tensor([0.9380, 0.6993], grad_fn=<SelectBackward>)
# tensor([0.2641, 0.4023])
# tensor([0.2641, 0.4020], grad_fn=<SelectBackward>)
# tensor([0.6592, 0.8304])
# tensor([0.6593, 0.8308], grad_fn=<SelectBackward>)
# tensor([0.8228, 0.2026])
# tensor([0.8226, 0.2023], grad_fn=<SelectBackward>)
# tensor([0.7919, 0.3003])
# tensor([0.7920, 0.3003], grad_fn=<SelectBackward>)
# tensor([0.1532, 0.3944])
# tensor([0.1531, 0.3943], grad_fn=<SelectBackward>)
# tensor([0.0087, 0.2089])
# tensor([0.0086, 0.2090], grad_fn=<SelectBackward>)
# tensor([0.8587, 0.0964])
# tensor([0.8586, 0.0961], grad_fn=<SelectBackward>)
# tensor([0.5098, 0.0541])
# tensor([0.5102, 0.0538], grad_fn=<SelectBackward>)
# tensor([0.1919, 0.6707])
# tensor([0.1915, 0.6704], grad_fn=<SelectBackward>)
# tensor([0.5965, 0.6740])
# tensor([0.5967, 0.6742], grad_fn=<SelectBackward>)
# tensor([0.2364, 0.1170])
# tensor([0.2361, 0.1172], grad_fn=<SelectBackward>)
# tensor([0.9676, 0.1028])
# tensor([0.9679, 0.1029], grad_fn=<SelectBackward>)
# tensor([0.1858, 0.7326])
# tensor([0.1858, 0.7325], grad_fn=<SelectBackward>)
# tensor([0.4307, 0.6911])
# tensor([0.4308, 0.6913], grad_fn=<SelectBackward>)
# tensor([0.1924, 0.9844])
# tensor([0.1946, 0.9842], grad_fn=<SelectBackward>)
# tensor([0.5990, 0.4704])
# tensor([0.5991, 0.4705], grad_fn=<SelectBackward>)
# tensor([0.4564, 0.6114])
# tensor([0.4564, 0.6112], grad_fn=<SelectBackward>)
# tensor([0.8372, 0.2160])
# tensor([0.8373, 0.2162], grad_fn=<SelectBackward>)
# tensor([0.7105, 0.6231])
# tensor([0.7103, 0.6230], grad_fn=<SelectBackward>)
# tensor([0.4884, 0.6593])
# tensor([0.4884, 0.6594], grad_fn=<SelectBackward>)
# tensor([0.5230, 0.3980])
# tensor([0.5231, 0.3979], grad_fn=<SelectBackward>)
# tensor([0.0374, 0.5013])
# tensor([0.0368, 0.5013], grad_fn=<SelectBackward>)
# tensor([0.8597, 0.0569])
# tensor([0.8600, 0.0567], grad_fn=<SelectBackward>)
# tensor([0.6019, 0.3644])
# tensor([0.6017, 0.3646], grad_fn=<SelectBackward>)
# tensor([0.4561, 0.8047])
# tensor([0.4562, 0.8046], grad_fn=<SelectBackward>)
# tensor([0.3610, 0.9467])
# tensor([0.3609, 0.9468], grad_fn=<SelectBackward>)
# tensor([0.7246, 0.0148])
# tensor([0.7243, 0.0148], grad_fn=<SelectBackward>)
# tensor([0.8451, 0.5471])
# tensor([0.8451, 0.5474], grad_fn=<SelectBackward>)
# tensor([0.1147, 0.4153])
# tensor([0.1148, 0.4153], grad_fn=<SelectBackward>)
# tensor([0.0429, 0.2701])
# tensor([0.0426, 0.2703], grad_fn=<SelectBackward>)
# tensor([0.4094, 0.7704])
# tensor([0.4095, 0.7701], grad_fn=<SelectBackward>)
# tensor([0.2754, 0.1836])
# tensor([0.2752, 0.1836], grad_fn=<SelectBackward>)
# tensor([0.0213, 0.6491])
# tensor([0.0210, 0.6489], grad_fn=<SelectBackward>)
# tensor([0.2783, 0.4160])
# tensor([0.2784, 0.4163], grad_fn=<SelectBackward>)
# tensor([0.7834, 0.9353])
# tensor([0.7834, 0.9347], grad_fn=<SelectBackward>)
# tensor([0.0995, 0.3910])
# tensor([0.0993, 0.3916], grad_fn=<SelectBackward>)
# tensor([0.2252, 0.6883])
# tensor([0.2252, 0.6879], grad_fn=<SelectBackward>)
# tensor([0.9499, 0.1244])
# tensor([0.9500, 0.1252], grad_fn=<SelectBackward>)
# tensor([0.7734, 0.5609])
# tensor([0.7734, 0.5601], grad_fn=<SelectBackward>)
# tensor([0.7648, 0.2486])
# tensor([0.7648, 0.2496], grad_fn=<SelectBackward>)
# tensor([0.7939, 0.7080])
# tensor([0.7937, 0.7068], grad_fn=<SelectBackward>)
# tensor([0.0010, 0.9696])
# tensor([0.0020, 0.9695], grad_fn=<SelectBackward>)
# tensor([0.4670, 0.4723])
# tensor([0.4666, 0.4711], grad_fn=<SelectBackward>)
# tensor([0.8063, 0.7926])
# tensor([0.8068, 0.7946], grad_fn=<SelectBackward>)
# tensor([0.8413, 0.7055])
# tensor([0.8407, 0.7034], grad_fn=<SelectBackward>)
# tensor([0.9798, 0.8033])
# tensor([0.9807, 0.8063], grad_fn=<SelectBackward>)
# tensor([0.4078, 0.2210])
# tensor([0.4071, 0.2190], grad_fn=<SelectBackward>)
# tensor([0.4183, 0.2440])
# tensor([0.4189, 0.2464], grad_fn=<SelectBackward>)
# tensor([0.7967, 0.0510])
# tensor([0.7958, 0.0472], grad_fn=<SelectBackward>)
# tensor([0.9242, 0.9508])
# tensor([0.9262, 0.9564], grad_fn=<SelectBackward>)
# tensor([0.2606, 0.9828])
# tensor([0.2585, 0.9777], grad_fn=<SelectBackward>)
# tensor([0.6104, 0.0916])
# tensor([0.6121, 0.0969], grad_fn=<SelectBackward>)
# tensor([0.7062, 0.1954])
# tensor([0.7036, 0.1890], grad_fn=<SelectBackward>)
# tensor([0.6192, 0.3494])
# tensor([0.6219, 0.3560], grad_fn=<SelectBackward>)
# tensor([0.5385, 0.1660])
# tensor([0.5360, 0.1596], grad_fn=<SelectBackward>)
# tensor([0.9866, 0.9398])
# tensor([0.9908, 0.9494], grad_fn=<SelectBackward>)
# tensor([0.0224, 0.9559])
# tensor([0.0186, 0.9495], grad_fn=<SelectBackward>)
# tensor([0.6628, 0.4817])
# tensor([0.6660, 0.4869], grad_fn=<SelectBackward>)
# tensor([0.2982, 0.0434])
# tensor([0.2964, 0.0408], grad_fn=<SelectBackward>)
# tensor([0.5481, 0.6839])
# tensor([0.5502, 0.6853], grad_fn=<SelectBackward>)
# tensor([0.6347, 0.5155])
# tensor([0.6334, 0.5162], grad_fn=<SelectBackward>)
# tensor([0.3731, 0.4447])
# tensor([0.3735, 0.4425], grad_fn=<SelectBackward>)
# tensor([0.8785, 0.3222])
# tensor([0.8785, 0.3279], grad_fn=<SelectBackward>)
# tensor([0.9711, 0.6189])
# tensor([0.9701, 0.6136], grad_fn=<SelectBackward>)
# tensor([0.0944, 0.0434])
# tensor([0.0947, 0.0463], grad_fn=<SelectBackward>)
# tensor([0.1593, 0.0601])
# tensor([0.1590, 0.0581], grad_fn=<SelectBackward>)
# tensor([0.3904, 0.4789])
# tensor([0.3913, 0.4811], grad_fn=<SelectBackward>)
# tensor([0.0077, 0.4165])
# tensor([0.0071, 0.4162], grad_fn=<SelectBackward>)
# tensor([0.2927, 0.1367])
# tensor([0.2935, 0.1365], grad_fn=<SelectBackward>)
# tensor([0.5985, 0.3591])
# tensor([0.5981, 0.3610], grad_fn=<SelectBackward>)
# tensor([0.7065, 0.9516])
# tensor([0.7067, 0.9480], grad_fn=<SelectBackward>)
# tensor([0.0457, 0.5650])
# tensor([0.0454, 0.5669], grad_fn=<SelectBackward>)
# tensor([0.5370, 0.8993])
# tensor([0.5369, 0.8960], grad_fn=<SelectBackward>)
# tensor([0.5087, 0.5113])
# tensor([0.5091, 0.5132], grad_fn=<SelectBackward>)
# tensor([0.2144, 0.4950])
# tensor([0.2142, 0.4939], grad_fn=<SelectBackward>)
# tensor([0.0577, 0.0905])
# tensor([0.0576, 0.0908], grad_fn=<SelectBackward>)
# tensor([0.9153, 0.4680])
# tensor([0.9154, 0.4691], grad_fn=<SelectBackward>)
# tensor([0.8734, 0.3532])
# tensor([0.8733, 0.3511], grad_fn=<SelectBackward>)
# tensor([0.9750, 0.8867])
# tensor([0.9753, 0.8893], grad_fn=<SelectBackward>)
# tensor([0.0634, 0.7287])
# tensor([0.0633, 0.7268], grad_fn=<SelectBackward>)
# tensor([0.6619, 0.2031])
# tensor([0.6619, 0.2053], grad_fn=<SelectBackward>)
# tensor([0.4971, 0.6208])
# tensor([0.4973, 0.6196], grad_fn=<SelectBackward>)
# tensor([0.3037, 0.0563])
# tensor([0.3038, 0.0563], grad_fn=<SelectBackward>)
# tensor([0.2972, 0.7126])
# tensor([0.2976, 0.7128], grad_fn=<SelectBackward>)
# tensor([0.3716, 0.4764])
# tensor([0.3712, 0.4757], grad_fn=<SelectBackward>)
# tensor([0.2912, 0.1414])
# tensor([0.2919, 0.1424], grad_fn=<SelectBackward>)
# tensor([0.1886, 0.5565])
# tensor([0.1880, 0.5551], grad_fn=<SelectBackward>)
# tensor([0.1410, 0.6071])
# tensor([0.1413, 0.6080], grad_fn=<SelectBackward>)
# tensor([0.9069, 0.7513])
# tensor([0.9067, 0.7501], grad_fn=<SelectBackward>)
# tensor([0.7596, 0.3154])
# tensor([0.7597, 0.3156], grad_fn=<SelectBackward>)
# tensor([0.8317, 0.5638])
# tensor([0.8319, 0.5636], grad_fn=<SelectBackward>)
# tensor([0.0898, 0.7486])
# tensor([0.0910, 0.7487], grad_fn=<SelectBackward>)
# tensor([0.8765, 0.1719])
# tensor([0.8769, 0.1726], grad_fn=<SelectBackward>)
# tensor([0.7546, 0.7808])
# tensor([0.7541, 0.7798], grad_fn=<SelectBackward>)
# tensor([0.1918, 0.3018])
# tensor([0.1920, 0.3024], grad_fn=<SelectBackward>)
# tensor([0.8497, 0.2817])
# tensor([0.8492, 0.2809], grad_fn=<SelectBackward>)
# tensor([0.7438, 0.5376])
# tensor([0.7443, 0.5382], grad_fn=<SelectBackward>)
# tensor([0.6360, 0.3572])
# tensor([0.6355, 0.3569], grad_fn=<SelectBackward>)
# tensor([0.3824, 0.3112])
# tensor([0.3824, 0.3113], grad_fn=<SelectBackward>)
# tensor([0.9842, 0.4458])
# tensor([0.9840, 0.4459], grad_fn=<SelectBackward>)
# tensor([0.8545, 0.8055])
# tensor([0.8545, 0.8050], grad_fn=<SelectBackward>)
# tensor([0.8169, 0.0987])
# tensor([0.8171, 0.0994], grad_fn=<SelectBackward>)
# tensor([0.8480, 0.4477])
# tensor([0.8478, 0.4471], grad_fn=<SelectBackward>)
# tensor([0.9500, 0.5195])
# tensor([0.9502, 0.5201], grad_fn=<SelectBackward>)
# tensor([0.0369, 0.1228])
# tensor([0.0370, 0.1221], grad_fn=<SelectBackward>)
# tensor([0.9158, 0.6876])
# tensor([0.9163, 0.6879], grad_fn=<SelectBackward>)
# tensor([0.6182, 0.7344])
# tensor([0.6179, 0.7344], grad_fn=<SelectBackward>)
# tensor([0.7371, 0.6511])
# tensor([0.7373, 0.6510], grad_fn=<SelectBackward>)
# tensor([0.0954, 0.5125])
# tensor([0.0951, 0.5125], grad_fn=<SelectBackward>)
# tensor([0.0496, 0.0370])
# tensor([0.0501, 0.0362], grad_fn=<SelectBackward>)
# tensor([0.8476, 0.1138])
# tensor([0.8475, 0.1143], grad_fn=<SelectBackward>)
# tensor([0.9053, 0.5837])
# tensor([0.9057, 0.5832], grad_fn=<SelectBackward>)
# tensor([0.4857, 0.4474])
# tensor([0.4857, 0.4476], grad_fn=<SelectBackward>)
# tensor([0.9311, 0.1113])
# tensor([0.9316, 0.1108], grad_fn=<SelectBackward>)
# tensor([0.0250, 0.1538])
# tensor([0.0248, 0.1539], grad_fn=<SelectBackward>)
# tensor([0.2027, 0.4722])
# tensor([0.2035, 0.4723], grad_fn=<SelectBackward>)
# tensor([0.5110, 0.2904])
# tensor([0.5105, 0.2905], grad_fn=<SelectBackward>)
# tensor([0.5403, 0.1172])
# tensor([0.5408, 0.1177], grad_fn=<SelectBackward>)
# tensor([0.0299, 0.4316])
# tensor([0.0295, 0.4319], grad_fn=<SelectBackward>)
# tensor([0.2297, 0.1583])
# tensor([0.2299, 0.1585], grad_fn=<SelectBackward>)
# tensor([0.8856, 0.1718])
# tensor([0.8852, 0.1717], grad_fn=<SelectBackward>)
# tensor([0.6716, 0.2064])
# tensor([0.6721, 0.2070], grad_fn=<SelectBackward>)
# tensor([0.9145, 0.3898])
# tensor([0.9140, 0.3896], grad_fn=<SelectBackward>)
# tensor([0.6809, 0.3705])
# tensor([0.6813, 0.3705], grad_fn=<SelectBackward>)
# tensor([0.5377, 0.1557])
# tensor([0.5375, 0.1557], grad_fn=<SelectBackward>)
# tensor([0.8736, 0.8375])
# tensor([0.8741, 0.8375], grad_fn=<SelectBackward>)
# tensor([0.5916, 0.5229])
# tensor([0.5910, 0.5229], grad_fn=<SelectBackward>)
# tensor([0.6674, 0.7668])
# tensor([0.6680, 0.7667], grad_fn=<SelectBackward>)
# tensor([0.4640, 0.3293])
# tensor([0.4635, 0.3295], grad_fn=<SelectBackward>)
# tensor([0.8652, 0.5943])
# tensor([0.8661, 0.5941], grad_fn=<SelectBackward>)
# tensor([0.9039, 0.3514])
# tensor([0.9029, 0.3523], grad_fn=<SelectBackward>)
# tensor([0.9542, 0.5327])
# tensor([0.9552, 0.5325], grad_fn=<SelectBackward>)
# tensor([0.0425, 0.1457])
# tensor([0.0419, 0.1457], grad_fn=<SelectBackward>)
# tensor([0.5296, 0.3400])
# tensor([0.5308, 0.3397], grad_fn=<SelectBackward>)
# tensor([0.2292, 0.3433])
# tensor([0.2283, 0.3436], grad_fn=<SelectBackward>)
# tensor([0.2367, 0.3370])
# tensor([0.2380, 0.3367], grad_fn=<SelectBackward>)
# tensor([0.7093, 0.8949])
# tensor([0.7070, 0.8956], grad_fn=<SelectBackward>)
# tensor([0.1849, 0.0258])
# tensor([0.1872, 0.0251], grad_fn=<SelectBackward>)
# tensor([0.2233, 0.7482])
# tensor([0.2210, 0.7488], grad_fn=<SelectBackward>)
# tensor([0.1995, 0.4406])
# tensor([0.2020, 0.4398], grad_fn=<SelectBackward>)
# tensor([0.2173, 0.0922])
# tensor([0.2147, 0.0930], grad_fn=<SelectBackward>)
# tensor([0.0032, 0.6771])
# tensor([0.0057, 0.6774], grad_fn=<SelectBackward>)
# tensor([0.3275, 0.4778])
# tensor([0.3230, 0.4788], grad_fn=<SelectBackward>)
# tensor([0.5690, 0.2923])
# tensor([0.5742, 0.2913], grad_fn=<SelectBackward>)
# tensor([0.0253, 0.6205])
# tensor([0.0206, 0.6214], grad_fn=<SelectBackward>)
# tensor([0.9747, 0.4067])
# tensor([0.9818, 0.4052], grad_fn=<SelectBackward>)
# tensor([0.9209, 0.5266])
# tensor([0.9142, 0.5282], grad_fn=<SelectBackward>)
# tensor([0.2533, 0.6265])
# tensor([0.2568, 0.6255], grad_fn=<SelectBackward>)
# tensor([0.6043, 0.1990])
# tensor([0.6015, 0.1996], grad_fn=<SelectBackward>)
# tensor([0.7471, 0.5876])
# tensor([0.7488, 0.5870], grad_fn=<SelectBackward>)
# tensor([0.5587, 0.3034])
# tensor([0.5588, 0.3036], grad_fn=<SelectBackward>)
# tensor([0.0027, 0.7558])
# tensor([0.0029, 0.7573], grad_fn=<SelectBackward>)
# tensor([0.0206, 0.3270])
# tensor([0.0222, 0.3268], grad_fn=<SelectBackward>)
# tensor([0.9056, 0.1397])
# tensor([0.9022, 0.1406], grad_fn=<SelectBackward>)
# tensor([0.4753, 0.8351])
# tensor([0.4790, 0.8342], grad_fn=<SelectBackward>)
# tensor([0.1615, 0.5017])
# tensor([0.1579, 0.5019], grad_fn=<SelectBackward>)
# tensor([0.4839, 0.2975])
# tensor([0.4860, 0.2971], grad_fn=<SelectBackward>)
# tensor([0.4106, 0.6802])
# tensor([0.4099, 0.6803], grad_fn=<SelectBackward>)
# tensor([0.8073, 0.9611])
# tensor([0.8070, 0.9611], grad_fn=<SelectBackward>)
# tensor([0.2886, 0.5146])
# tensor([0.2895, 0.5144], grad_fn=<SelectBackward>)
# tensor([0.6931, 0.2697])
# tensor([0.6913, 0.2697], grad_fn=<SelectBackward>)
# tensor([0.9772, 0.1694])
# tensor([0.9800, 0.1687], grad_fn=<SelectBackward>)
# tensor([0.3638, 0.4264])
# tensor([0.3621, 0.4266], grad_fn=<SelectBackward>)
# tensor([0.7514, 0.3659])
# tensor([0.7534, 0.3656], grad_fn=<SelectBackward>)
# tensor([0.6445, 0.8138])
# tensor([0.6434, 0.8139], grad_fn=<SelectBackward>)
# tensor([0.3601, 0.4299])
# tensor([0.3603, 0.4299], grad_fn=<SelectBackward>)
# tensor([0.0944, 0.1030])
# tensor([0.0950, 0.1028], grad_fn=<SelectBackward>)
# tensor([0.0834, 0.7652])
# tensor([0.0828, 0.7658], grad_fn=<SelectBackward>)
# tensor([0.1595, 0.3332])
# tensor([0.1605, 0.3332], grad_fn=<SelectBackward>)
# tensor([0.1186, 0.9649])
# tensor([0.1175, 0.9652], grad_fn=<SelectBackward>)
# tensor([0.1019, 0.4680])
# tensor([0.1030, 0.4678], grad_fn=<SelectBackward>)
# tensor([0.3442, 0.5066])
# tensor([0.3432, 0.5067], grad_fn=<SelectBackward>)
# tensor([0.1534, 0.6063])
# tensor([0.1539, 0.6064], grad_fn=<SelectBackward>)
# tensor([0.1741, 0.1052])
# tensor([0.1743, 0.1058], grad_fn=<SelectBackward>)
# tensor([0.3074, 0.0054])
# tensor([0.3063, 0.0059], grad_fn=<SelectBackward>)
# tensor([0.9201, 0.1094])
# tensor([0.9211, 0.1089], grad_fn=<SelectBackward>)
# tensor([0.7885, 0.2534])
# tensor([0.7875, 0.2539], grad_fn=<SelectBackward>)
# tensor([0.0310, 0.4648])
# tensor([0.0314, 0.4647], grad_fn=<SelectBackward>)
# tensor([0.9769, 0.4537])
# tensor([0.9756, 0.4540], grad_fn=<SelectBackward>)
# tensor([0.5830, 0.0586])
# tensor([0.5835, 0.0581], grad_fn=<SelectBackward>)
# tensor([0.6806, 0.5981])
# tensor([0.6802, 0.5981], grad_fn=<SelectBackward>)
# tensor([0.4398, 0.8190])
# tensor([0.4399, 0.8191], grad_fn=<SelectBackward>)
# tensor([0.0690, 0.8023])
# tensor([0.0685, 0.8024], grad_fn=<SelectBackward>)
# tensor([0.3261, 0.7619])
# tensor([0.3256, 0.7621], grad_fn=<SelectBackward>)
# tensor([0.6788, 0.3178])
# tensor([0.6794, 0.3174], grad_fn=<SelectBackward>)
# tensor([0.0834, 0.4080])
# tensor([0.0826, 0.4083], grad_fn=<SelectBackward>)
# tensor([0.2923, 0.3767])
# tensor([0.2929, 0.3765], grad_fn=<SelectBackward>)
# tensor([0.8888, 0.7065])
# tensor([0.8883, 0.7067], grad_fn=<SelectBackward>)
# tensor([0.7830, 0.5555])
# tensor([0.7835, 0.5554], grad_fn=<SelectBackward>)
# tensor([0.6892, 0.1973])
# tensor([0.6891, 0.1973], grad_fn=<SelectBackward>)
# tensor([0.2612, 0.2849])
# tensor([0.2613, 0.2852], grad_fn=<SelectBackward>)
# tensor([0.5409, 0.2527])
# tensor([0.5410, 0.2528], grad_fn=<SelectBackward>)
# tensor([0.7236, 0.4751])
# tensor([0.7232, 0.4751], grad_fn=<SelectBackward>)
# tensor([0.7038, 0.1854])
# tensor([0.7042, 0.1852], grad_fn=<SelectBackward>)
# tensor([0.5945, 0.8427])
# tensor([0.5939, 0.8429], grad_fn=<SelectBackward>)
# tensor([0.6596, 0.3503])
# tensor([0.6600, 0.3502], grad_fn=<SelectBackward>)
# tensor([0.9021, 0.2765])
# tensor([0.9017, 0.2767], grad_fn=<SelectBackward>)
# tensor([0.1544, 0.3259])
# tensor([0.1549, 0.3260], grad_fn=<SelectBackward>)
# tensor([0.5820, 0.0470])
# tensor([0.5818, 0.0469], grad_fn=<SelectBackward>)
# tensor([0.9691, 0.4478])
# tensor([0.9691, 0.4475], grad_fn=<SelectBackward>)
# tensor([0.4813, 0.4555])
# tensor([0.4812, 0.4558], grad_fn=<SelectBackward>)
# tensor([0.4069, 0.6557])
# tensor([0.4067, 0.6556], grad_fn=<SelectBackward>)
# tensor([0.5906, 0.3195])
# tensor([0.5907, 0.3197], grad_fn=<SelectBackward>)
# tensor([0.1395, 0.5713])
# tensor([0.1388, 0.5707], grad_fn=<SelectBackward>)
# tensor([0.6292, 0.1174])
# tensor([0.6293, 0.1174], grad_fn=<SelectBackward>)
# tensor([0.3391, 0.1196])
# tensor([0.3391, 0.1194], grad_fn=<SelectBackward>)
# tensor([0.0816, 0.4277])
# tensor([0.0815, 0.4280], grad_fn=<SelectBackward>)
# tensor([0.2734, 0.7887])
# tensor([0.2731, 0.7885], grad_fn=<SelectBackward>)
# tensor([0.7071, 0.7947])
# tensor([0.7074, 0.7950], grad_fn=<SelectBackward>)
# tensor([0.8884, 0.1368])
# tensor([0.8882, 0.1365], grad_fn=<SelectBackward>)
# tensor([0.3173, 0.2261])
# tensor([0.3172, 0.2263], grad_fn=<SelectBackward>)
# tensor([0.6317, 0.5049])
# tensor([0.6316, 0.5045], grad_fn=<SelectBackward>)
# tensor([0.7643, 0.1242])
# tensor([0.7643, 0.1246], grad_fn=<SelectBackward>)
# tensor([0.8502, 0.2941])
# tensor([0.8502, 0.2939], grad_fn=<SelectBackward>)
# tensor([0.3792, 0.8024])
# tensor([0.3790, 0.8030], grad_fn=<SelectBackward>)
# tensor([0.6221, 0.4719])
# tensor([0.6222, 0.4712], grad_fn=<SelectBackward>)
# tensor([0.0829, 0.4975])
# tensor([0.0826, 0.4979], grad_fn=<SelectBackward>)
# tensor([0.1965, 0.2815])
# tensor([0.1965, 0.2810], grad_fn=<SelectBackward>)
# tensor([0.0843, 0.2409])
# tensor([0.0841, 0.2416], grad_fn=<SelectBackward>)
# tensor([0.6657, 0.4108])
# tensor([0.6657, 0.4096], grad_fn=<SelectBackward>)
# tensor([0.3068, 0.7158])
# tensor([0.3069, 0.7170], grad_fn=<SelectBackward>)
# tensor([0.4185, 0.2836])
# tensor([0.4184, 0.2826], grad_fn=<SelectBackward>)
# tensor([0.9640, 0.5807])
# tensor([0.9641, 0.5827], grad_fn=<SelectBackward>)
# tensor([0.0959, 0.1552])
# tensor([0.0958, 0.1536], grad_fn=<SelectBackward>)
# tensor([0.9644, 0.9718])
# tensor([0.9648, 0.9747], grad_fn=<SelectBackward>)
# tensor([0.3481, 0.8485])
# tensor([0.3477, 0.8461], grad_fn=<SelectBackward>)
# tensor([0.2313, 0.0872])
# tensor([0.2314, 0.0891], grad_fn=<SelectBackward>)
# tensor([0.1202, 0.0805])
# tensor([0.1196, 0.0794], grad_fn=<SelectBackward>)
# tensor([0.6236, 0.4777])
# tensor([0.6243, 0.4813], grad_fn=<SelectBackward>)
# tensor([0.3274, 0.5539])
# tensor([0.3265, 0.5501], grad_fn=<SelectBackward>)
# tensor([0.2612, 0.4201])
# tensor([0.2621, 0.4237], grad_fn=<SelectBackward>)
# tensor([0.6770, 0.5786])
# tensor([0.6755, 0.5729], grad_fn=<SelectBackward>)
# tensor([0.5368, 0.2322])
# tensor([0.5380, 0.2376], grad_fn=<SelectBackward>)
# tensor([0.7168, 0.4033])
# tensor([0.7150, 0.3962], grad_fn=<SelectBackward>)
# epoch : 49/50, loss = 0.000003
# epoch : 50/50, loss = 0.000003

# %%
torch.save(model.state_dict(), "model/vanilla_100n_64emb.pt")
